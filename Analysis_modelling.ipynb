# %%
import pandas as pd

# %%
data=pd.read_excel("Employees.xlsx")

# %%
data
# Out:
#       No   First Name Last Name  Gender Start Date  Years  \
# 0      1       Ghadir     Hmshw    Male 2018-04-04      2
# 1      2         Omar    Hishan    Male 2020-05-21      0
# 2      3        Ailya    Sharaf  Female 2017-09-28      3
# 3      4         Lwiy     Qbany    Male 2018-08-14      2
# 4      5        Ahmad     Bikri    Male 2020-03-11      0
# ..   ...          ...       ...     ...        ...    ...
# 684  685         Sari     Hanna    Male 2020-05-26      0
# 685  686      Eubayda      Kayd    Male 2020-06-03      0
# 686  687       Khalil    Alkalu    Male 2017-07-11      3
# 687  688      Muhamad    Shrbjy    Male 2018-05-30      2
# 688  689  Abd Albasit   AlAhmar    Male 2020-08-05      0
#
#                  Department               Country Center  Monthly Salary  \
# 0           Quality Control                 Egypt   West            1560
# 1           Quality Control          Saudi Arabia   West            3247
# ...

# %%
data.head(5)
# Out:
#    No First Name Last Name  Gender Start Date  Years          Department  \
# 0   1     Ghadir     Hmshw    Male 2018-04-04      2     Quality Control
# 1   2       Omar    Hishan    Male 2020-05-21      0     Quality Control
# 2   3      Ailya    Sharaf  Female 2017-09-28      3  Major Mfg Projects
# 3   4       Lwiy     Qbany    Male 2018-08-14      2       Manufacturing
# 4   5      Ahmad     Bikri    Male 2020-03-11      0       Manufacturing
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
# 4                 Egypt   Main             970          11640       5.0
#
#    Sick Leaves  Unpaid Leaves  Overtime Hours
# 0            1              0             183
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Years           689 non-null    int64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    int64
#  11  Job Rate        689 non-null    float64
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(6)
# memory usage: 80.9+ KB

# %%
data.shape
# Out:
# (689, 15)

# %%
data.isna().sum()
# Out:
# No                0
# First Name        0
# Last Name         0
# Gender            0
# Start Date        0
# Years             0
# Department        0
# Country           0
# Center            0
# Monthly Salary    0
# Annual Salary     0
# Job Rate          0
# Sick Leaves       0
# Unpaid Leaves     0
# Overtime Hours    0
# dtype: int64

# %%
#data.dropna(inplace=True) for cleaning dropping up NA values in the dataset

# %%
#checking duplicates
data.duplicated().sum()
#data.drop_duplicated(inplace = true ) for dropping duplicates
# Out:
# np.int64(0)

# %%
data.head(5)
# Out:
#    No First Name Last Name  Gender Start Date  Years          Department  \
# 0   1     Ghadir     Hmshw    Male 2018-04-04      2     Quality Control
# 1   2       Omar    Hishan    Male 2020-05-21      0     Quality Control
# 2   3      Ailya    Sharaf  Female 2017-09-28      3  Major Mfg Projects
# 3   4       Lwiy     Qbany    Male 2018-08-14      2       Manufacturing
# 4   5      Ahmad     Bikri    Male 2020-03-11      0       Manufacturing
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
# 4                 Egypt   Main             970          11640       5.0
#
#    Sick Leaves  Unpaid Leaves  Overtime Hours
# 0            1              0             183
# ...

# %%
import matplotlib.pyplot as plt

# %%
data["Gender"].value_counts()
# Out:
# Gender
# Male      449
# Female    240
# Name: count, dtype: int64

# %%
data["Gender"].value_counts().sort_values(ascending = True).plot(kind="pie")
plt.title("pie chart of gender column")
plt.ylabel("")
plt.show()

# %%
data.head(4)
# Out:
#    No First Name Last Name  Gender Start Date  Years          Department  \
# 0   1     Ghadir     Hmshw    Male 2018-04-04      2     Quality Control
# 1   2       Omar    Hishan    Male 2020-05-21      0     Quality Control
# 2   3      Ailya    Sharaf  Female 2017-09-28      3  Major Mfg Projects
# 3   4       Lwiy     Qbany    Male 2018-08-14      2       Manufacturing
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
#
#    Sick Leaves  Unpaid Leaves  Overtime Hours
# 0            1              0             183
# 1            0              5             198
# 2            0              3             192
# 3            0              0               7

# %%
plt.hist(data["Job Rate"])
plt.title("Histogram of job rate")
plt.xlabel("rate")
plt.ylabel("count")
plt.show()

# %%
data["Job Rate"].describe()
# Out:
# count    689.000000
# mean       3.586357
# std        1.350125
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        5.000000
# max        5.000000
# Name: Job Rate, dtype: float64

# %%
data.head()
# Out:
#    No First Name Last Name  Gender Start Date  Years          Department  \
# 0   1     Ghadir     Hmshw    Male 2018-04-04      2     Quality Control
# 1   2       Omar    Hishan    Male 2020-05-21      0     Quality Control
# 2   3      Ailya    Sharaf  Female 2017-09-28      3  Major Mfg Projects
# 3   4       Lwiy     Qbany    Male 2018-08-14      2       Manufacturing
# 4   5      Ahmad     Bikri    Male 2020-03-11      0       Manufacturing
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
# 4                 Egypt   Main             970          11640       5.0
#
#    Sick Leaves  Unpaid Leaves  Overtime Hours
# 0            1              0             183
# ...

# %%
data.groupby("Department")["Annual Salary"].mean().sort_values(ascending=False).head(7).plot(kind="bar")
plt.title("Average Annual Salary by Department")
plt.xlabel("Departmet")
plt.ylabel("Average Salary")
plt.show()

# %%
data
# Out:
#       No   First Name Last Name  Gender Start Date  Years  \
# 0      1       Ghadir     Hmshw    Male 2018-04-04      2
# 1      2         Omar    Hishan    Male 2020-05-21      0
# 2      3        Ailya    Sharaf  Female 2017-09-28      3
# 3      4         Lwiy     Qbany    Male 2018-08-14      2
# 4      5        Ahmad     Bikri    Male 2020-03-11      0
# ..   ...          ...       ...     ...        ...    ...
# 684  685         Sari     Hanna    Male 2020-05-26      0
# 685  686      Eubayda      Kayd    Male 2020-06-03      0
# 686  687       Khalil    Alkalu    Male 2017-07-11      3
# 687  688      Muhamad    Shrbjy    Male 2018-05-30      2
# 688  689  Abd Albasit   AlAhmar    Male 2020-08-05      0
#
#                  Department               Country Center  Monthly Salary  \
# 0           Quality Control                 Egypt   West            1560
# 1           Quality Control          Saudi Arabia   West            3247
# ...

# %%
data.groupby("Center")["Monthly Salary"].mean()
# Out:
# Center
# East     2274.021277
# Main     2054.776892
# North    2064.811594
# South    1981.153846
# West     2068.672269
# Name: Monthly Salary, dtype: float64

# %%
data.groupby("Center")["Monthly Salary"].mean().sort_values(ascending=False)
# Out:
# Center
# East     2274.021277
# West     2068.672269
# North    2064.811594
# Main     2054.776892
# South    1981.153846
# Name: Monthly Salary, dtype: float64

# %%
data["Country"].unique()
# Out:
# array(['Egypt', 'Saudi Arabia', 'United Arab Emirates', 'Syria',
#        'Lebanon'], dtype=object)

# %%
data.groupby("Country")["Job Rate"].mean().sort_values(ascending=False).plot(kind="bar")
plt.title("Job rate by country")
plt.xlabel("Country")
plt.ylabel("job rate")
plt.show()

# %%
data
# Out:
#       No   First Name Last Name  Gender Start Date  Years  \
# 0      1       Ghadir     Hmshw    Male 2018-04-04      2
# 1      2         Omar    Hishan    Male 2020-05-21      0
# 2      3        Ailya    Sharaf  Female 2017-09-28      3
# 3      4         Lwiy     Qbany    Male 2018-08-14      2
# 4      5        Ahmad     Bikri    Male 2020-03-11      0
# ..   ...          ...       ...     ...        ...    ...
# 684  685         Sari     Hanna    Male 2020-05-26      0
# 685  686      Eubayda      Kayd    Male 2020-06-03      0
# 686  687       Khalil    Alkalu    Male 2017-07-11      3
# 687  688      Muhamad    Shrbjy    Male 2018-05-30      2
# 688  689  Abd Albasit   AlAhmar    Male 2020-08-05      0
#
#                  Department               Country Center  Monthly Salary  \
# 0           Quality Control                 Egypt   West            1560
# 1           Quality Control          Saudi Arabia   West            3247
# ...

# %%
plt.hist(data["Overtime Hours"])
plt.title("Overtime Hours Distribution")
plt.xlabel("Overtime hrs")
plt.ylabel("Frequency")
plt.show()

# %%
data["Annual Salary"].describe()
# Out:
# count      689.000000
# mean     24818.420900
# std       9159.470878
# min       8436.000000
# 25%      17232.000000
# 50%      24924.000000
# 75%      32184.000000
# max      41400.000000
# Name: Annual Salary, dtype: float64

# %%
# linear regression model
data.columns
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary', 'Annual Salary',
#        'Job Rate', 'Sick Leaves', 'Unpaid Leaves', 'Overtime Hours'],
#       dtype='object')

# %%
X = data[["Years", "Job Rate"]]  # List of strings, not a tuple
Y = data["Annual Salary"]

# %%
# %pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
len(Y_train)
# Out:
# 551

# %%
len(X_test)
# Out:
# 138

# %%
X
# Out:
#      Years  Job Rate
# 0        2       3.0
# 1        0       1.0
# 2        3       2.0
# 3        2       3.0
# 4        0       5.0
# ..     ...       ...
# 684      0       2.0
# 685      0       3.0
# 686      3       5.0
# 687      2       3.0
# 688      0       5.0
#
# [689 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([24660.9258488 , 25370.15628015, 24114.13532698, 25730.71857515,
#        26091.28087015, 25823.83268856, 24381.58350856, 25102.70809856,
#        25370.15628015, 25195.82221197, 25730.71857515, 24835.25991698,
#        23579.23896381, 24649.03169015, 24381.58350856, 25195.82221197,
#        24381.58350856, 23579.23896381, 24649.03169015, 25102.70809856,
#        25556.38450697, 24114.13532698, 24381.58350856, 23846.68714539,
#        25556.38450697, 25370.15628015, 24114.13532698, 25556.38450697,
#        25195.82221197, 24835.25991698, 24300.3635538 , 25463.27039356,
#        24381.58350856, 24649.03169015, 25370.15628015, 24294.41647448,
#        24561.86465606, 24835.25991698, 26091.28087015, 24381.58350856,
#        25102.70809856, 24114.13532698, 24829.31283765, 24829.31283765,
#        24381.58350856, 24114.13532698, 25102.70809856, 24300.3635538 ,
#        24649.03169015, 25463.27039356, 25370.15628015, 24381.58350856,
# ...

# %%
prediction = lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(prediction,Y_test)
# Out:
# 8172.2260394870855

# %%
# training extra models
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import root_mean_squared_error

import pandas as pd
import joblib

# %%
# Random Forest Regressor
rf = RandomForestRegressor(random_state=42)
rf.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Gradient Boosting Regressor
gbr = GradientBoostingRegressor(random_state=42)
gbr.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error

# Putting all models in a dictionary for easy comparison
models = {
    "Linear Regression": lr,
    "Random Forest": rf,
    "Gradient Boosting": gbr
}

# Initializing a list to store the results
results = []

# Looping through each model and calculate metrics
for name, model in models.items():
    y_pred = model.predict(X_test)
    mae = mean_absolute_error(Y_test, y_pred)
    rmse = root_mean_squared_error(Y_test, y_pred)  
    r2 = r2_score(Y_test, y_pred)
    
    results.append({
        "Model": name,
        "MAE": round(mae, 2),
        "RMSE": round(rmse, 2),
        "R²": round(r2, 3)
    })

# %%
# Convert the list of dictionaries into a pandas DataFrame
results_df = pd.DataFrame(results)

# Sort models by MAE (lower is better)
results_df = results_df.sort_values(by="MAE")

# Display results
print(results_df)
# Out:
#                Model      MAE     RMSE     R²
# 0  Linear Regression  8172.23  9330.78 -0.002
# 2  Gradient Boosting  8257.70  9479.25 -0.034
# 1      Random Forest  8290.66  9542.41 -0.048

# %%
# Save all models with filenames matching the Streamlit app
joblib.dump(lr, "linearmodel.pkl")
joblib.dump(rf, "randomforest_model.pkl")
joblib.dump(gbr, "gradientboosting_model.pkl")
# Out:
# ['gradientboosting_model.pkl']
